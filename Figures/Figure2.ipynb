# %%
import matplotlib.pyplot as plt

#replace these with your actual logged values if needed
epochs = list(range(1, 48))  #or however many epochs you ran

top1 = [
0.1963,0.2194,0.2334,0.2475,0.2552,0.2674,0.2711,0.2742,0.2765,0.2799,
0.2831,0.2841,0.2870,0.2877,0.2893,0.2923,0.2922,0.2939,0.2936,0.2933,
0.2952,0.2961,0.2961,0.2968,0.2971,0.2974,0.2974,0.2976,0.2983,0.2992,
0.2978,0.2990,0.2981,0.2984,0.2978,0.2982,0.2976,0.2995,0.2993,0.2978,
0.2989,0.2991,0.2965,0.2994,0.2993,0.2991,0.2987
]

top3 = [
0.4238,0.4579,0.4771,0.4936,0.5058,0.5197,0.5252,0.5291,0.5323,0.5375,
0.5426,0.5440,0.5472,0.5475,0.5496,0.5525,0.5534,0.5544,0.5547,0.5558,
0.5576,0.5572,0.5574,0.5577,0.5582,0.5586,0.5580,0.5582,0.5594,0.5597,
0.5593,0.5594,0.5598,0.5597,0.5593,0.5599,0.5593,0.5604,0.5606,0.5594,
0.5601,0.5602,0.5590,0.5602,0.5605,0.5602,0.5600
]

plt.figure(figsize=(7, 5))
plt.plot(epochs, top1, label="Top-1 Accuracy")
plt.plot(epochs, top3, label="Top-3 Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Model Accuracy During Training")
plt.legend()
plt.tight_layout()
plt.show()
